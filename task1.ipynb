# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/titanic.csv",index_col=0)
df.head()
# Out:
#         survived                                             name     sex  \
# pclass
# 1              1                    Allen, Miss. Elisabeth Walton  female
# 1              1                   Allison, Master. Hudson Trevor    male
# 1              0                     Allison, Miss. Helen Loraine  female
# 1              0             Allison, Mr. Hudson Joshua Creighton    male
# 1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#            age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# pclass
# 1           29      0      0   24160  211.3375       B5        S    2    ?
# 1       0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 1            2      1      2  113781    151.55  C22 C26        S    ?    ?
# 1           30      1      2  113781    151.55  C22 C26        S    ?  135
# 1           25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                               home.dest
# pclass
# ...

# %%
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, *, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
plt.figure
plt.bar(df.sex.unique(),df.sex.value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
df.describe(include=np.object)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_13088\3211851552.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.describe(include=np.object)
#                         name   sex   age    ticket  fare cabin embarked  boat  \
# count                   1309  1309  1309      1309  1309  1309     1309  1309
# unique                  1307     2    99       929   282   187        4    28
# top     Connolly, Miss. Kate  male     ?  CA. 2343  8.05     ?        S     ?
# freq                       2   843   263        11    60  1014      914   823
#
#         body home.dest
# count   1309      1309
# unique   122       370
# top        ?         ?
# freq    1188       564

# %%
df.describe(include=np.number,percentiles=[.5,.01])
# Out:
#           survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000
# mean      0.381971     0.498854     0.385027
# std       0.486055     1.041658     0.865560
# min       0.000000     0.000000     0.000000
# 1%        0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000
# max       1.000000     8.000000     9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 3
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   survived   1309 non-null   int64
#  1   name       1309 non-null   object
#  2   sex        1309 non-null   object
#  3   age        1309 non-null   object
#  4   sibsp      1309 non-null   int64
#  5   parch      1309 non-null   int64
#  6   ticket     1309 non-null   object
#  7   fare       1309 non-null   object
#  8   cabin      1309 non-null   object
#  9   embarked   1309 non-null   object
#  10  boat       1309 non-null   object
#  11  body       1309 non-null   object
#  12  home.dest  1309 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 143.2+ KB

# %%
df.dtypes
# Out:
# survived      int64
# name         object
# sex          object
# age          object
# sibsp         int64
# parch         int64
# ticket       object
# fare         object
# cabin        object
# embarked     object
# boat         object
# body         object
# home.dest    object
# dtype: object

# %%
df.sum(numeric_only=True)
# Out:
# survived    500
# sibsp       653
# parch       504
# dtype: int64

# %%
df.mode(numeric_only=True)
# Out:
#    survived  sibsp  parch
# 0         0      0      0

# %%
df.name.nunique(dropna=True)
# Out:
# 1307

# %%
df.sibsp.nlargest(5,keep='all')
# Out:
# pclass
# 3    8
# 3    8
# 3    8
# 3    8
# 3    8
# 3    8
# 3    8
# 3    8
# 3    8
# Name: sibsp, dtype: int64

# %%
df.nlargest(5,columns=['sibsp','parch'])
# Out:
#         survived                               name     sex   age  sibsp  \
# pclass
# 3              0         Sage, Master. Thomas Henry    male     ?      8
# 3              0        Sage, Master. William Henry    male  14.5      8
# 3              0                    Sage, Miss. Ada  female     ?      8
# 3              0       Sage, Miss. Constance Gladys  female     ?      8
# 3              0  Sage, Miss. Dorothy Edith 'Dolly'  female     ?      8
#
#         parch    ticket   fare cabin embarked boat body home.dest
# pclass
# 3           2  CA. 2343  69.55     ?        S    ?    ?         ?
# 3           2  CA. 2343  69.55     ?        S    ?   67         ?
# 3           2  CA. 2343  69.55     ?        S    ?    ?         ?
# 3           2  CA. 2343  69.55     ?        S    ?    ?         ?
# 3           2  CA. 2343  69.55     ?        S    ?    ?         ?

# %%
df[["survived",'parch','name']].describe(include=["object","int64"])
# Out:
#            survived        parch                  name
# count   1309.000000  1309.000000                  1309
# unique          NaN          NaN                  1307
# top             NaN          NaN  Connolly, Miss. Kate
# freq            NaN          NaN                     2
# mean       0.381971     0.385027                   NaN
# std        0.486055     0.865560                   NaN
# min        0.000000     0.000000                   NaN
# 25%        0.000000     0.000000                   NaN
# 50%        0.000000     0.000000                   NaN
# 75%        1.000000     0.000000                   NaN
# max        1.000000     9.000000                   NaN
